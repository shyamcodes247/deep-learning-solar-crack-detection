# %% [markdown]
# The following code prints the first data image out using Python and some supporting Python libraries.

# %%
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt

img_path = list(Path("../data/PVEL_S/test/defect").rglob("*.jpg"))[0]  # first jpg
print(img_path)

img = Image.open(img_path)
plt.imshow(img)
plt.axis("off")
# Out:
# ../data/PVEL_S/test/defect/0918.jpg
# (-0.5, 1023.5, 1023.5, -0.5)
